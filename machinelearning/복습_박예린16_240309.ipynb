# %%
import seaborn as sns

# %%
tt =sns.load_dataset('titanic')

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd

# %%
type(tt)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tt.pclass)
# Out:
# pandas.core.series.Series

# %%
# shape
tt.shape
# Out:
# (891, 15)

# %%
#columns 
tt.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
tt_col=list(tt.columns)

# %%
tt_col
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tt.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
tt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %% [markdown]
# - 데이터를 살펴볼 수 있는 다양한 문법

# %%
tt.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tt.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
tt.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
tt.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
tt['survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
tt[['survived','age']]
# Out:
#      survived   age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
tt_sp=tt[['age','survived','fare']]

# %%
tt_sp
# Out:
#       age  survived     fare
# 0    22.0         0   7.2500
# 1    38.0         1  71.2833
# 2    26.0         1   7.9250
# 3    35.0         1  53.1000
# 4    35.0         0   8.0500
# ..    ...       ...      ...
# 886  27.0         0  13.0000
# 887  19.0         1  30.0000
# 888   NaN         0  23.4500
# 889  26.0         1  30.0000
# 890  32.0         0   7.7500
#
# [891 rows x 3 columns]

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
tt.iloc[100]
# Out:
# survived                 0
# pclass                   3
# sex                 female
# age                   28.0
# sibsp                    0
# parch                    0
# fare                7.8958
# embarked                 S
# class                Third
# who                  woman
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 100, dtype: object

# %%
tt.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/indexes/range.py:392, in RangeIndex.get_loc(self, key, method, tolerance)
#     391 try:
# --> 392     return self._range.index(new_key)
#     393 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 tt.loc[-1]
#
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
num_row=tt.shape[0]

# %%
lst_idx = num_row -1

# %%
tt.loc[lst_idx]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
mid_num = 75

# %%
tt.loc[mid_num]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   25.0
# sibsp                    0
# parch                    0
# fare                  7.65
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                     F
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 75, dtype: object

# %%
tt.iloc[-1]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
tt.loc[[1, 10, 20, 30,890]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 30          0       1    male  40.0      0      0  27.7208        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 20     man        True  NaN  Southampton    no   True
# 30     man        True  NaN    Cherbourg    no   True
# 890    man        True  NaN   Queenstown    no   True

# %%
tt.iloc[[1, 10, 20, 30,890]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 30          0       1    male  40.0      0      0  27.7208        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 20     man        True  NaN  Southampton    no   True
# 30     man        True  NaN    Cherbourg    no   True
# 890    man        True  NaN   Queenstown    no   True

# %%
tt.loc[::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[::3]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_sp_idx=tt.iloc[1:10:2]

# %%
tt_sp_idx
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 3  woman       False    C  Southampton   yes  False
# 5    man        True  NaN   Queenstown    no   True
# 7  child       False  NaN  Southampton    no  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_sp_idx.loc[2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/indexes/range.py:392, in RangeIndex.get_loc(self, key, method, tolerance)
#     391 try:
# --> 392     return self._range.index(new_key)
#     393 except ValueError as err:
#
# ValueError: 2 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 tt_sp_idx.loc[2]
#
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
tt_sp_idx.iloc[2]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                   NaN
# sibsp                   0
# parch                   0
# fare               8.4583
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 5, dtype: object

# %% [markdown]
# - 슬라이싱과 컬럼을 접근해 보자!

# %%
tt.loc[1:50,['age']]
# Out:
#      age
# 1   38.0
# 2   26.0
# 3   35.0
# 4   35.0
# 5    NaN
# 6   54.0
# 7    2.0
# 8   27.0
# 9   14.0
# 10   4.0
# 11  58.0
# 12  20.0
# 13  39.0
# 14  14.0
# 15  55.0
# 16   2.0
# 17   NaN
# 18  31.0
# 19   NaN
# 20  35.0
# 21  34.0
# 22  15.0
# 23  28.0
# 24   8.0
# 25  38.0
# 26   NaN
# 27  19.0
# 28   NaN
# 29   NaN
# 30  40.0
# 31   NaN
# 32   NaN
# 33  66.0
# 34  28.0
# 35  42.0
# 36   NaN
# 37  21.0
# 38  18.0
# 39  14.0
# 40  40.0
# 41  27.0
# 42   NaN
# 43   3.0
# 44  19.0
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49  18.0
# 50   7.0

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[1:50,['age','survived']]
# Out:
#      age  survived
# 1   38.0         1
# 2   26.0         1
# 3   35.0         1
# 4   35.0         0
# 5    NaN         0
# 6   54.0         0
# 7    2.0         0
# 8   27.0         1
# 9   14.0         1
# 10   4.0         1
# 11  58.0         1
# 12  20.0         0
# 13  39.0         0
# 14  14.0         0
# 15  55.0         1
# 16   2.0         0
# 17   NaN         1
# 18  31.0         0
# 19   NaN         1
# 20  35.0         0
# 21  34.0         1
# 22  15.0         1
# 23  28.0         1
# 24   8.0         0
# 25  38.0         1
# 26   NaN         0
# 27  19.0         0
# 28   NaN         1
# 29   NaN         0
# 30  40.0         0
# 31   NaN         1
# 32   NaN         1
# 33  66.0         0
# 34  28.0         0
# 35  42.0         0
# 36   NaN         1
# 37  21.0         0
# 38  18.0         0
# 39  14.0         1
# 40  40.0         0
# 41  27.0         0
# 42   NaN         0
# 43   3.0         1
# 44  19.0         1
# 45   NaN         0
# 46   NaN         0
# ...

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.iloc[1:50,[3,4,-1]] # iloc은 넘버로만 지정해서 접근해야 한다
# Out:
#      age  sibsp  alone
# 1   38.0      1  False
# 2   26.0      0   True
# 3   35.0      1  False
# 4   35.0      0   True
# 5    NaN      0   True
# 6   54.0      0   True
# 7    2.0      3  False
# 8   27.0      0  False
# 9   14.0      1  False
# 10   4.0      1  False
# 11  58.0      0   True
# 12  20.0      0   True
# 13  39.0      1  False
# 14  14.0      0   True
# 15  55.0      0   True
# 16   2.0      4  False
# 17   NaN      0   True
# 18  31.0      1  False
# 19   NaN      0   True
# 20  35.0      0   True
# 21  34.0      0   True
# 22  15.0      0   True
# 23  28.0      0   True
# 24   8.0      3  False
# 25  38.0      1  False
# 26   NaN      0   True
# 27  19.0      3  False
# 28   NaN      0   True
# 29   NaN      0   True
# 30  40.0      0   True
# 31   NaN      1  False
# 32   NaN      0   True
# 33  66.0      0   True
# 34  28.0      1  False
# 35  42.0      1  False
# 36   NaN      0   True
# 37  21.0      0   True
# 38  18.0      2  False
# 39  14.0      1  False
# ...

# %%
tt.iloc[1:50,[3,4,-1]]['age'].loc[10]
# Out:
# 4.0

# %%
tt.iloc[1:50,[3,4,-1]]['age']
# Out:
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# 20    35.0
# 21    34.0
# 22    15.0
# 23    28.0
# 24     8.0
# 25    38.0
# 26     NaN
# 27    19.0
# 28     NaN
# 29     NaN
# 30    40.0
# 31     NaN
# 32     NaN
# 33    66.0
# 34    28.0
# 35    42.0
# 36     NaN
# 37    21.0
# 38    18.0
# 39    14.0
# 40    40.0
# 41    27.0
# 42     NaN
# 43     3.0
# 44    19.0
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49    18.0
# Name: age, dtype: float64

# %%
tt.iloc[1:50,[3,4,-1]]['age'].loc[10]
# Out:
# 4.0

# %% [markdown]
# - 인덱스 3번 째 값중에서 age와 class를 추출한다!

# %%
tt.loc[3][['age','class']]
# Out:
# age       35.0
# class    First
# Name: 3, dtype: object

# %%
tt[['age','class']].loc[3]
# Out:
# age       35.0
# class    First
# Name: 3, dtype: object

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Q.여기서 iloc 대신 loc을 쓰면 에러가 뜨는데 왜그런건가요? tt.loc[1:50,[3,4]]

# %%
tt.iloc[1:50,[3,4]]
# Out:
#      age  sibsp
# 1   38.0      1
# 2   26.0      0
# 3   35.0      1
# 4   35.0      0
# 5    NaN      0
# 6   54.0      0
# 7    2.0      3
# 8   27.0      0
# 9   14.0      1
# 10   4.0      1
# 11  58.0      0
# 12  20.0      0
# 13  39.0      1
# 14  14.0      0
# 15  55.0      0
# 16   2.0      4
# 17   NaN      0
# 18  31.0      1
# 19   NaN      0
# 20  35.0      0
# 21  34.0      0
# 22  15.0      0
# 23  28.0      0
# 24   8.0      3
# 25  38.0      1
# 26   NaN      0
# 27  19.0      3
# 28   NaN      0
# 29   NaN      0
# 30  40.0      0
# 31   NaN      1
# 32   NaN      0
# 33  66.0      0
# 34  28.0      1
# 35  42.0      1
# 36   NaN      0
# 37  21.0      0
# 38  18.0      2
# 39  14.0      1
# 40  40.0      1
# 41  27.0      1
# 42   NaN      0
# 43   3.0      1
# 44  19.0      0
# 45   NaN      0
# 46   NaN      1
# 47   NaN      0
# 48   NaN      2
# 49  18.0      1

# %%
rn_3=list(range(0,100,3))

# %%
tt.iloc[rn_3]
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.00      1      0    7.2500        S   Third
# 3          1       1  female  35.00      1      0   53.1000        S   First
# 6          0       1    male  54.00      0      0   51.8625        S   First
# 9          1       2  female  14.00      1      0   30.0708        C  Second
# 12         0       3    male  20.00      0      0    8.0500        S   Third
# 15         1       2  female  55.00      0      0   16.0000        S  Second
# 18         0       3  female  31.00      1      0   18.0000        S   Third
# 21         1       2    male  34.00      0      0   13.0000        S  Second
# 24         0       3  female   8.00      3      1   21.0750        S   Third
# 27         0       1    male  19.00      3      2  263.0000        S   First
# 30         0       1    male  40.00      0      0   27.7208        C   First
# ...

# %%
rn_col = list(range(0,10,2))

# %%
tt.iloc[:,rn_col] #컬럼을 range로 list 넣은 후 원하는 컬럼만 데이터 추출 가능
# Out:
#      survived     sex  sibsp     fare   class
# 0           0    male      1   7.2500   Third
# 1           1  female      1  71.2833   First
# 2           1  female      0   7.9250   Third
# 3           1  female      1  53.1000   First
# 4           0    male      0   8.0500   Third
# ..        ...     ...    ...      ...     ...
# 886         0    male      0  13.0000  Second
# 887         1  female      0  30.0000   First
# 888         0  female      1  23.4500   Third
# 889         1    male      0  30.0000   First
# 890         0    male      0   7.7500   Third
#
# [891 rows x 5 columns]

# %%
tt['fare'].mean()
# Out:
# 32.204207968574636

# %%
tt.fare.mean()
# Out:
# 32.204207968574636

# %%
tt.fare.sum()
# Out:
# 28693.9493

# %%
tt.fare.count()
# Out:
# 891

# %%
tt.fare.median()
# Out:
# 14.4542

# %%
tt.fare.sum()/tt.fare.count()
# Out:
# 32.204207968574636

# %%
tt.fare.mean()
# Out:
# 32.204207968574636

# %%
tt.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
tt.groupby('sex')['fare'].mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
tt.groupby('embark_town')['fare'].mean()
# Out:
# embark_town
# Cherbourg      59.954144
# Queenstown     13.276030
# Southampton    27.079812
# Name: fare, dtype: float64

# %%
tt.groupby('sex')['survived'].sum()
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
tt.groupby('sex')['fare'].mean()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
tt.groupby('sex')[['fare','age']].mean()
# Out:
#              fare        age
# sex
# female  44.479818  27.915709
# male    25.523893  30.726645
