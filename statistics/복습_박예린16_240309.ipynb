# %%
import seaborn as sns
tt = sns.load_dataset('titanic')

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd
type(tt)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tt.age)
# Out:
# pandas.core.series.Series

# %%
print(tt.age)
print(tt['age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
tt.shape
# Out:
# (891, 15)

# %%
tt.shape[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97e3f4f969c7> in <module>
# ----> 1 tt.shape[-1]
#
# NameError: name 'tt' is not defined

# %%
tt.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
tt_col=list(tt.columns)

# %%
tt_col
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tt.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
tt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
tt.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tt.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
tt.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
tt.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
tt['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
tt[['age','survived']]
# Out:
#       age  survived
# 0    22.0         0
# 1    38.0         1
# 2    26.0         1
# 3    35.0         1
# 4    35.0         0
# ..    ...       ...
# 886  27.0         0
# 887  19.0         1
# 888   NaN         0
# 889  26.0         1
# 890  32.0         0
#
# [891 rows x 2 columns]

# %%
tt_agsu=tt[['age','survived']]

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
tt.iloc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
tt.loc[100]
# Out:
# survived                 0
# pclass                   3
# sex                 female
# age                   28.0
# sibsp                    0
# parch                    0
# fare                7.8958
# embarked                 S
# class                Third
# who                  woman
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 100, dtype: object

# %%
tt.iloc[100]
# Out:
# survived                 0
# pclass                   3
# sex                 female
# age                   28.0
# sibsp                    0
# parch                    0
# fare                7.8958
# embarked                 S
# class                Third
# who                  woman
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 100, dtype: object

# %%
tt.iloc[-1]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
num_row = tt.shape[0]

last_idx =num_row -1

# %%
tt.loc[last_idx]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
tt.iloc[last_idx]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
mid_idx = 543

# %%
print(tt.loc[mid_idx])
print(tt.iloc[mid_idx])
# Out:
# survived                 1
# pclass                   2
# sex                   male
# age                   32.0
# sibsp                    1
# parch                    0
# fare                  26.0
# embarked                 S
# class               Second
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 543, dtype: object
# survived                 1
# pclass                   2
# sex                   male
# age                   32.0
# sibsp                    1
# parch                    0
# fare                  26.0
# embarked                 S
# class               Second
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 543, dtype: object

# %%
tt.loc[[1,2,4,5,6,7,100]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# 100         0       3  female  28.0      0      0   7.8958        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# ...

# %%
tt.iloc[[1,2,4,5,6,7,100]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# 100         0       3  female  28.0      0      0   7.8958        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# ...

# %%
tt.loc[::]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.loc[0:100:4]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 12          0       3    male  20.0      0      0    8.0500        S   Third
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 20          0       2    male  35.0      0      0   26.0000        S  Second
# 24          0       3  female   8.0      3      1   21.0750        S   Third
# 28          1       3  female   NaN      0      0    7.8792        Q   Third
# 32          1       3  female   NaN      0      0    7.7500        Q   Third
# 36          1       3    male   NaN      0      0    7.2292        C   Third
# 40          0       3  female  40.0      1      0    9.4750        S   Third
# ...

# %%
tt.iloc[0:100:4]
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 12         0       3    male  20.0      0      0    8.0500        S   Third
# 16         0       3    male   2.0      4      1   29.1250        Q   Third
# 20         0       2    male  35.0      0      0   26.0000        S  Second
# 24         0       3  female   8.0      3      1   21.0750        S   Third
# 28         1       3  female   NaN      0      0    7.8792        Q   Third
# 32         1       3  female   NaN      0      0    7.7500        Q   Third
# 36         1       3    male   NaN      0      0    7.2292        C   Third
# 40         0       3  female  40.0      1      0    9.4750        S   Third
# ...

# %%
tt.loc[:,['age']]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
tt.loc[::,['age']]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
tt.loc[::,['age','fare']]
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
tt.iloc[::,[2,3]]
# Out:
#         sex   age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
tt.iloc[::,[2,3,-1]]
# Out:
#         sex   age  alone
# 0      male  22.0  False
# 1    female  38.0  False
# 2    female  26.0   True
# 3    female  35.0  False
# 4      male  35.0   True
# ..      ...   ...    ...
# 886    male  27.0   True
# 887  female  19.0   True
# 888  female   NaN  False
# 889    male  26.0   True
# 890    male  32.0   True
#
# [891 rows x 3 columns]

# %%
tt_sp=tt.loc[0:10:2]

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_sp
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 10         1       3  female   4.0      1      1  16.7000        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 2   woman       False  NaN  Southampton   yes   True
# 4     man        True  NaN  Southampton    no   True
# 6     man        True    E  Southampton    no   True
# 8   woman       False  NaN  Southampton   yes  False
# 10  child       False    G  Southampton   yes  False

# %%
tt_sp.iloc[1] #reindexing
# Out:
# survived                 1
# pclass                   3
# sex                 female
# age                   26.0
# sibsp                    0
# parch                    0
# fare                 7.925
# embarked                 S
# class                Third
# who                  woman
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                  yes
# alone                 True
# Name: 2, dtype: object

# %%
tt_sp
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 10         1       3  female   4.0      1      1  16.7000        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 2   woman       False  NaN  Southampton   yes   True
# 4     man        True  NaN  Southampton    no   True
# 6     man        True    E  Southampton    no   True
# 8   woman       False  NaN  Southampton   yes  False
# 10  child       False    G  Southampton   yes  False

# %%
tt_sp.loc[10]
# Out:
# survived                 1
# pclass                   3
# sex                 female
# age                    4.0
# sibsp                    1
# parch                    1
# fare                  16.7
# embarked                 S
# class                Third
# who                  child
# adult_male           False
# deck                     G
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 10, dtype: object

# %%
num_3=list(range(0,100,3))

# %%
tt.loc[num_3]['embark_town']
# Out:
# 0     Southampton
# 3     Southampton
# 6     Southampton
# 9       Cherbourg
# 12    Southampton
# 15    Southampton
# 18    Southampton
# 21    Southampton
# 24    Southampton
# 27    Southampton
# 30      Cherbourg
# 33    Southampton
# 36      Cherbourg
# 39      Cherbourg
# 42      Cherbourg
# 45    Southampton
# 48      Cherbourg
# 51    Southampton
# 54      Cherbourg
# 57      Cherbourg
# 60      Cherbourg
# 63    Southampton
# 66    Southampton
# 69    Southampton
# 72    Southampton
# 75    Southampton
# 78    Southampton
# 81    Southampton
# 84    Southampton
# 87    Southampton
# 90    Southampton
# 93    Southampton
# 96      Cherbourg
# 99    Southampton
# Name: embark_town, dtype: object

# %%
tt['embark_town'].loc[num_3]
# Out:
# 0     Southampton
# 3     Southampton
# 6     Southampton
# 9       Cherbourg
# 12    Southampton
# 15    Southampton
# 18    Southampton
# 21    Southampton
# 24    Southampton
# 27    Southampton
# 30      Cherbourg
# 33    Southampton
# 36      Cherbourg
# 39      Cherbourg
# 42      Cherbourg
# 45    Southampton
# 48      Cherbourg
# 51    Southampton
# 54      Cherbourg
# 57      Cherbourg
# 60      Cherbourg
# 63    Southampton
# 66    Southampton
# 69    Southampton
# 72    Southampton
# 75    Southampton
# 78    Southampton
# 81    Southampton
# 84    Southampton
# 87    Southampton
# 90    Southampton
# 93    Southampton
# 96      Cherbourg
# 99    Southampton
# Name: embark_town, dtype: object

# %%
tt[['embark_town','fare']].loc[num_3]['fare']
# Out:
# 0       7.2500
# 3      53.1000
# 6      51.8625
# 9      30.0708
# 12      8.0500
# 15     16.0000
# 18     18.0000
# 21     13.0000
# 24     21.0750
# 27    263.0000
# 30     27.7208
# 33     10.5000
# 36      7.2292
# 39     11.2417
# 42      7.8958
# 45      8.0500
# 48     21.6792
# 51      7.8000
# 54     61.9792
# 57      7.2292
# 60      7.2292
# 63     27.9000
# 66     10.5000
# 69      8.6625
# 72     73.5000
# 75      7.6500
# 78     29.0000
# 81      9.5000
# 84     10.5000
# 87      8.0500
# 90      8.0500
# 93     20.5750
# 96     34.6542
# 99     26.0000
# Name: fare, dtype: float64

# %%
tt[['embark_town','fare']].loc[num_3]['fare'].loc[54]
# Out:
# 61.9792

# %%
tt[['embark_town','fare']].loc[num_3]['fare'].loc[2:20]
# Out:
# 3     53.1000
# 6     51.8625
# 9     30.0708
# 12     8.0500
# 15    16.0000
# 18    18.0000
# Name: fare, dtype: float64

# %%
len(tt[['embark_town','fare']]['fare'])
# Out:
# 891

# %% [markdown]
# ## 기초통계치를 같이 응용해서 분석하자!

# %%
tt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
import numpy as np

# %%
tt.fare.mean()
# Out:
# 32.204207968574636

# %%
np.mean(tt.fare)
# Out:
# 32.204207968574636

# %%
np.std(tt.fare)
# Out:
# 49.6655344447741

# %%
np.sum(tt.fare)
# Out:
# 28693.9493

# %%
np.argmax(tt.fare)
# Out:
# 258

# %%
np.argmin(tt.fare)
# Out:
# 179

# %%
tt.fare.loc[258]
# Out:
# 512.3292

# %%
tt.fare.loc[179]
# Out:
# 0.0

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
tt.groupby('embarked')['fare'].sum()
# Out:
# embarked
# C    10072.2962
# Q     1022.2543
# S    17439.3988
# Name: fare, dtype: float64

# %%
tt.groupby('embarked')['fare'].mean()
# Out:
# embarked
# C    59.954144
# Q    13.276030
# S    27.079812
# Name: fare, dtype: float64

# %%
tt.groupby('embarked')['fare','age'].mean()
# Out:
# /var/folders/sz/167qwb595mqgwry5mm8685n00000gn/T/ipykernel_30192/2350520844.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tt.groupby('embarked')['fare','age'].mean()
#                fare        age
# embarked
# C         59.954144  30.814769
# Q         13.276030  28.089286
# S         27.079812  29.445397

# %%
tt.groupby('embarked')[['fare','age']].mean()
# Out:
#                fare        age
# embarked
# C         59.954144  30.814769
# Q         13.276030  28.089286
# S         27.079812  29.445397
